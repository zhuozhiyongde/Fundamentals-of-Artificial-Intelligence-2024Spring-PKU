# %% [markdown]
# ## 依赖引入

# %%
import warnings

import lightgbm as lgb
import pandas as pd
from sklearn.metrics import mean_absolute_percentage_error
from sklearn.preprocessing import StandardScaler

# %matplotlib inline
warnings.filterwarnings("ignore")

# %% [markdown]
# ## 数据读取

# %%
train = pd.read_csv("./data/train.csv")
train_y = train[["SALE PRICE"]]
train_X = train
del train_X["SALE PRICE"]

test_X = pd.read_csv("./data/test.csv")
test_y = pd.read_csv("./data/test_groundtruth.csv")

print("train_X:", train_X.shape)
print("train_y:", train_y.shape)
print("test_X:", test_X.shape)
print("test_y:", test_y.shape)
# Out:
# train_X: (43064, 19)
# train_y: (43064, 1)
# test_X: (10767, 19)
# test_y: (10767, 1)

# %%
train.head()
# Out:
#    BOROUGH             NEIGHBORHOOD  \
# 0        1  UPPER EAST SIDE (79-96)
# 1        4               HOLLISWOOD
# 2        3     DOWNTOWN-FULTON MALL
# 3        4           FLUSHING-NORTH
# 4        3               PARK SLOPE
#
#                        BUILDING CLASS CATEGORY TAX CLASS AT PRESENT  BLOCK  \
# 0  13 CONDOS - ELEVATOR APARTMENTS                                2   1569
# 1  10 COOPS - ELEVATOR APARTMENTS                                 2  10538
# 2  13 CONDOS - ELEVATOR APARTMENTS                                2    170
# 3  13 CONDOS - ELEVATOR APARTMENTS                                2   4410
# 4  09 COOPS - WALKUP APARTMENTS                                  2C   1067
#
#     LOT BUILDING CLASS AT PRESENT                    ADDRESS APARTMENT NUMBER  \
# 0  1027                        R4       402 EAST 90TH STREET               5A
# 1    70                        D4  87-50 204TH   STREET, B42
# 2  1042                        R4           265 STATE STREET              910
# 3  1023                        R4           137-11 32 AVENUE               4W
# 4    29                        C6    862 PRESIDENT STREET, 1
#
#    ZIP CODE  RESIDENTIAL UNITS  COMMERCIAL UNITS  TOTAL UNITS  \
# 0     10128                  1                 0            1
# 1     11423                  0                 0            0
# 2     11201                  1                 0            1
# 3     11354                  1                 0            1
# 4     11215                  0                 0            0
#
#   LAND SQUARE FEET GROSS SQUARE FEET  YEAR BUILT  TAX CLASS AT TIME OF SALE  \
# 0              -                 -          1910                          2
# 1              -                 -          1954                          2
# 2                0                 0        2014                          2
# 3              -                 -             0                          2
# 4                0                 0        1920                          2
#
#   BUILDING CLASS AT TIME OF SALE            SALE DATE
# 0                             R4  2016-09-30 00:00:00
# 1                             D4  2017-02-10 00:00:00
# 2                             R4  2017-01-25 00:00:00
# 3                             R4  2017-03-17 00:00:00
# 4                             C6  2016-09-09 00:00:00

# %%
num_train_samples = len(train_X)

data_X = pd.concat([train_X, test_X])

# %% [markdown]
# ## 处理数值数据

# %%
# 处理无效数据，替换无效值、0 为中位数
# 定义需要处理的列
invalid_columns = ["LAND SQUARE FEET", "GROSS SQUARE FEET"]

# 遍历每一列进行处理
for column in invalid_columns:
    # 替换无效值为 0
    train[column].replace(" -  ", "0", inplace=True)
    # 转换数据类型为 int64
    train[column] = train[column].astype("int64")

    # 筛选出非 0 的行，计算均值
    valid_index = train[column] != 0
    column_mean = int(train[valid_index][column].median())
    print("Mean: ", column_mean)
    # 替换 0 值为均值
    train.loc[train[column] == 0, column] = column_mean

    # 同样的处理应用到 data_X 上
    data_X[column].replace(" -  ", "0", inplace=True)
    data_X[column] = data_X[column].astype("int64")
    data_X.loc[data_X[column] == 0, column] = column_mean
    print(data_X[column].value_counts().sort_values(ascending=False).head(10))
# Out:
# Mean:  2500
# LAND SQUARE FEET
# 2500    29104
# 2000     2298
# 4000     1836
# 1800      740
# 3000      736
# 5000      558
# 2400      326
# 1900      304
# 6000      277
# 1600      269
# Name: count, dtype: int64
# Mean:  1800
# GROSS SQUARE FEET
# 1800    27995
# 1440      230
# 1600      230
# 2400      225
# 2000      220
# 1200      190
# 1280      184
# 3000      167
# 1152      161
# 1224      160
# Name: count, dtype: int64

# %% [markdown]
# ## 移除无效字段

# %%
del data_X["APARTMENT NUMBER"]
del data_X["BUILDING CLASS AT PRESENT"]

# %% [markdown]
# ## 处理分类数据

# %%
# 处理 ADDRESS 列，移除多余信息
data_X["ADDRESS"] = data_X["ADDRESS"].apply(lambda x: x.split(",")[0])
# 转换为分类变量
# 需要转换为category类型的列名列表
category_columns = [
    "BOROUGH",
    "BUILDING CLASS CATEGORY",
    "TAX CLASS AT PRESENT",
    "TAX CLASS AT TIME OF SALE",
    "NEIGHBORHOOD",
    "ZIP CODE",
    "BLOCK",
    "BUILDING CLASS AT TIME OF SALE",
]

numerical_catagory_columns = ["ADDRESS"]

# 进行类型转换
for column in category_columns:
    data_X[column] = data_X[column].astype("category")

# 对于 numerical_catagory_columns，需要转换为 category 类型，并且转换为数值
for column in numerical_catagory_columns:
    data_X[column] = data_X[column].astype("category")
    data_X[column] = data_X[column].cat.codes

# import seaborn as sns
# sns.regplot(x="ADDRESS", y="SALE PRICE", data=train)
data_X.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 53831 entries, 0 to 10766
# Data columns (total 17 columns):
#  #   Column                          Non-Null Count  Dtype
# ---  ------                          --------------  -----
#  0   BOROUGH                         53831 non-null  category
#  1   NEIGHBORHOOD                    53831 non-null  category
#  2   BUILDING CLASS CATEGORY         53831 non-null  category
#  3   TAX CLASS AT PRESENT            53831 non-null  category
#  4   BLOCK                           53831 non-null  category
#  5   LOT                             53831 non-null  int64
#  6   ADDRESS                         53831 non-null  int32
#  7   ZIP CODE                        53831 non-null  category
#  8   RESIDENTIAL UNITS               53831 non-null  int64
#  9   COMMERCIAL UNITS                53831 non-null  int64
#  10  TOTAL UNITS                     53831 non-null  int64
#  11  LAND SQUARE FEET                53831 non-null  int64
#  12  GROSS SQUARE FEET               53831 non-null  int64
#  13  YEAR BUILT                      53831 non-null  int64
#  14  TAX CLASS AT TIME OF SALE       53831 non-null  category
#  15  BUILDING CLASS AT TIME OF SALE  53831 non-null  category
#  16  SALE DATE                       53831 non-null  object
# dtypes: category(8), int32(1), int64(7), object(1)
# memory usage: 4.8+ MB

# %% [markdown]
# ## 处理日期数据

# %%
# 从 SALE DATE 中提取出年、月、日
data_X["SALE DATE"] = pd.to_datetime(data_X["SALE DATE"])
data_X["SALE YEAR"] = data_X["SALE DATE"].dt.year
data_X["SALE MONTH"] = data_X["SALE DATE"].dt.month
data_X["SALE DAY"] = data_X["SALE DATE"].dt.day
del data_X["SALE DATE"]
data_X.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 53831 entries, 0 to 10766
# Data columns (total 19 columns):
#  #   Column                          Non-Null Count  Dtype
# ---  ------                          --------------  -----
#  0   BOROUGH                         53831 non-null  category
#  1   NEIGHBORHOOD                    53831 non-null  category
#  2   BUILDING CLASS CATEGORY         53831 non-null  category
#  3   TAX CLASS AT PRESENT            53831 non-null  category
#  4   BLOCK                           53831 non-null  category
#  5   LOT                             53831 non-null  int64
#  6   ADDRESS                         53831 non-null  int32
#  7   ZIP CODE                        53831 non-null  category
#  8   RESIDENTIAL UNITS               53831 non-null  int64
#  9   COMMERCIAL UNITS                53831 non-null  int64
#  10  TOTAL UNITS                     53831 non-null  int64
#  11  LAND SQUARE FEET                53831 non-null  int64
#  12  GROSS SQUARE FEET               53831 non-null  int64
#  13  YEAR BUILT                      53831 non-null  int64
#  14  TAX CLASS AT TIME OF SALE       53831 non-null  category
#  15  BUILDING CLASS AT TIME OF SALE  53831 non-null  category
#  16  SALE YEAR                       53831 non-null  int32
#  17  SALE MONTH                      53831 non-null  int32
#  18  SALE DAY                        53831 non-null  int32
# dtypes: category(8), int32(4), int64(7)
# memory usage: 5.0 MB

# %% [markdown]
# ## 归一化数值数据

# %%
all_columns = data_X.columns
# 删除类别列 category_columns
one_hot_columns = [
    "BOROUGH",
    "BUILDING CLASS CATEGORY",
    "TAX CLASS AT PRESENT",
    "TAX CLASS AT TIME OF SALE",
    "NEIGHBORHOOD",
    "ZIP CODE",
    "BLOCK",
    "BUILDING CLASS AT TIME OF SALE",
]
numerical_columns = list(set(all_columns) - set(one_hot_columns))
print("numerical_columns:", numerical_columns)
scaler = StandardScaler()
data_X[numerical_columns] = scaler.fit_transform(data_X[numerical_columns])
# Out:
# numerical_columns: ['TOTAL UNITS', 'GROSS SQUARE FEET', 'YEAR BUILT', 'COMMERCIAL UNITS', 'LAND SQUARE FEET', 'ADDRESS', 'SALE MONTH', 'LOT', 'SALE YEAR', 'RESIDENTIAL UNITS', 'SALE DAY']

# %% [markdown]
# ## One-Hot 编码

# %%
# 对于类别数据，使用 one-hot 编码
one_hot_encoded = pd.get_dummies(data_X[one_hot_columns])
one_hot_encoded.info(verbose=True, memory_usage=True)
data_X = data_X.drop(one_hot_columns, axis=1)
data_X = pd.concat([data_X, one_hot_encoded], axis=1)
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 53831 entries, 0 to 10766
# Data columns (total 10873 columns):
#  #      Column                                                                Dtype
# ---     ------                                                                -----
#  0      BOROUGH_1                                                             bool
#  1      BOROUGH_2                                                             bool
#  2      BOROUGH_3                                                             bool
#  3      BOROUGH_4                                                             bool
#  4      BOROUGH_5                                                             bool
#  5      BUILDING CLASS CATEGORY_01 ONE FAMILY DWELLINGS                       bool
#  6      BUILDING CLASS CATEGORY_02 TWO FAMILY DWELLINGS                       bool
#  7      BUILDING CLASS CATEGORY_03 THREE FAMILY DWELLINGS                     bool
#  8      BUILDING CLASS CATEGORY_04 TAX CLASS 1 CONDOS                         bool
#  9      BUILDING CLASS CATEGORY_05 TAX CLASS 1 VACANT LAND                    bool
#  10     BUILDING CLASS CATEGORY_06 TAX CLASS 1 - OTHER                        bool
#  11     BUILDING CLASS CATEGORY_07 RENTALS - WALKUP APARTMENTS                bool
#  12     BUILDING CLASS CATEGORY_08 RENTALS - ELEVATOR APARTMENTS              bool
#  13     BUILDING CLASS CATEGORY_09 COOPS - WALKUP APARTMENTS                  bool
#  14     BUILDING CLASS CATEGORY_10 COOPS - ELEVATOR APARTMENTS                bool
#  15     BUILDING CLASS CATEGORY_11A CONDO-RENTALS                             bool
#  16     BUILDING CLASS CATEGORY_12 CONDOS - WALKUP APARTMENTS                 bool
#  17     BUILDING CLASS CATEGORY_13 CONDOS - ELEVATOR APARTMENTS               bool
#  18     BUILDING CLASS CATEGORY_14 RENTALS - 4-10 UNIT                        bool
#  19     BUILDING CLASS CATEGORY_15 CONDOS - 2-10 UNIT RESIDENTIAL             bool
#  20     BUILDING CLASS CATEGORY_16 CONDOS - 2-10 UNIT WITH COMMERCIAL UNIT    bool
#  21     BUILDING CLASS CATEGORY_17 CONDO COOPS                                bool
#  22     BUILDING CLASS CATEGORY_21 OFFICE BUILDINGS                           bool
#  23     BUILDING CLASS CATEGORY_22 STORE BUILDINGS                            bool
#  24     BUILDING CLASS CATEGORY_23 LOFT BUILDINGS                             bool
#  25     BUILDING CLASS CATEGORY_26 OTHER HOTELS                               bool
#  26     BUILDING CLASS CATEGORY_27 FACTORIES                                  bool
#  27     BUILDING CLASS CATEGORY_28 COMMERCIAL CONDOS                          bool
#  28     BUILDING CLASS CATEGORY_29 COMMERCIAL GARAGES                         bool
#  29     BUILDING CLASS CATEGORY_30 WAREHOUSES                                 bool
#  30     BUILDING CLASS CATEGORY_31 COMMERCIAL VACANT LAND                     bool
#  31     BUILDING CLASS CATEGORY_32 HOSPITAL AND HEALTH FACILITIES             bool
#  32     BUILDING CLASS CATEGORY_33 EDUCATIONAL FACILITIES                     bool
#  33     BUILDING CLASS CATEGORY_35 INDOOR PUBLIC AND CULTURAL FACILITIES      bool
#  34     BUILDING CLASS CATEGORY_36 OUTDOOR RECREATIONAL FACILITIES            bool
#  35     BUILDING CLASS CATEGORY_37 RELIGIOUS FACILITIES                       bool
#  36     BUILDING CLASS CATEGORY_38 ASYLUMS AND HOMES                          bool
#  37     BUILDING CLASS CATEGORY_39 TRANSPORTATION FACILITIES                  bool
#  38     BUILDING CLASS CATEGORY_41 TAX CLASS 4 - OTHER                        bool
#  39     BUILDING CLASS CATEGORY_42 CONDO CULTURAL/MEDICAL/EDUCATIONAL/ETC     bool
#  40     BUILDING CLASS CATEGORY_43 CONDO OFFICE BUILDINGS                     bool
#  41     BUILDING CLASS CATEGORY_44 CONDO PARKING                              bool
#  42     BUILDING CLASS CATEGORY_45 CONDO HOTELS                               bool
#  43     BUILDING CLASS CATEGORY_46 CONDO STORE BUILDINGS                      bool
#  44     BUILDING CLASS CATEGORY_47 CONDO NON-BUSINESS STORAGE                 bool
#  45     BUILDING CLASS CATEGORY_48 CONDO TERRACES/GARDENS/CABANAS             bool
#  46     TAX CLASS AT PRESENT_                                                 bool
#  47     TAX CLASS AT PRESENT_1                                                bool
#  48     TAX CLASS AT PRESENT_1A                                               bool
#  49     TAX CLASS AT PRESENT_1B                                               bool
#  50     TAX CLASS AT PRESENT_1C                                               bool
#  51     TAX CLASS AT PRESENT_2                                                bool
#  52     TAX CLASS AT PRESENT_2A                                               bool
#  53     TAX CLASS AT PRESENT_2B                                               bool
#  54     TAX CLASS AT PRESENT_2C                                               bool
#  55     TAX CLASS AT PRESENT_4                                                bool
#  56     TAX CLASS AT TIME OF SALE_1                                           bool
#  57     TAX CLASS AT TIME OF SALE_2                                           bool
#  58     TAX CLASS AT TIME OF SALE_4                                           bool
#  59     NEIGHBORHOOD_AIRPORT LA GUARDIA                                       bool
#  60     NEIGHBORHOOD_ALPHABET CITY                                            bool
#  61     NEIGHBORHOOD_ANNADALE                                                 bool
#  62     NEIGHBORHOOD_ARDEN HEIGHTS                                            bool
#  63     NEIGHBORHOOD_ARROCHAR                                                 bool
#  64     NEIGHBORHOOD_ARROCHAR-SHORE ACRES                                     bool
#  65     NEIGHBORHOOD_ARVERNE                                                  bool
#  66     NEIGHBORHOOD_ASTORIA                                                  bool
#  67     NEIGHBORHOOD_BATH BEACH                                               bool
#  68     NEIGHBORHOOD_BATHGATE                                                 bool
#  69     NEIGHBORHOOD_BAY RIDGE                                                bool
#  70     NEIGHBORHOOD_BAYCHESTER                                               bool
#  71     NEIGHBORHOOD_BAYSIDE                                                  bool
#  72     NEIGHBORHOOD_BEDFORD PARK/NORWOOD                                     bool
#  73     NEIGHBORHOOD_BEDFORD STUYVESANT                                       bool
#  74     NEIGHBORHOOD_BEECHHURST                                               bool
#  75     NEIGHBORHOOD_BELLE HARBOR                                             bool
#  76     NEIGHBORHOOD_BELLEROSE                                                bool
#  77     NEIGHBORHOOD_BELMONT                                                  bool
#  78     NEIGHBORHOOD_BENSONHURST                                              bool
#  79     NEIGHBORHOOD_BERGEN BEACH                                             bool
#  80     NEIGHBORHOOD_BLOOMFIELD                                               bool
#  81     NEIGHBORHOOD_BOERUM HILL                                              bool
#  82     NEIGHBORHOOD_BOROUGH PARK                                             bool
#  83     NEIGHBORHOOD_BRIARWOOD                                                bool
#  84     NEIGHBORHOOD_BRIGHTON BEACH                                           bool
#  85     NEIGHBORHOOD_BROAD CHANNEL                                            bool
#  86     NEIGHBORHOOD_BRONX PARK                                               bool
#  87     NEIGHBORHOOD_BRONXDALE                                                bool
#  88     NEIGHBORHOOD_BROOKLYN HEIGHTS                                         bool
#  89     NEIGHBORHOOD_BROWNSVILLE                                              bool
#  90     NEIGHBORHOOD_BULLS HEAD                                               bool
#  91     NEIGHBORHOOD_BUSH TERMINAL                                            bool
#  92     NEIGHBORHOOD_BUSHWICK                                                 bool
#  93     NEIGHBORHOOD_CAMBRIA HEIGHTS                                          bool
#  94     NEIGHBORHOOD_CANARSIE                                                 bool
#  95     NEIGHBORHOOD_CARROLL GARDENS                                          bool
#  96     NEIGHBORHOOD_CASTLE HILL/UNIONPORT                                    bool
#  97     NEIGHBORHOOD_CASTLETON CORNERS                                        bool
#  98     NEIGHBORHOOD_CHELSEA                                                  bool
#  99     NEIGHBORHOOD_CHINATOWN                                                bool
#  100    NEIGHBORHOOD_CITY ISLAND                                              bool
#  101    NEIGHBORHOOD_CITY ISLAND-PELHAM STRIP                                 bool
#  102    NEIGHBORHOOD_CIVIC CENTER                                             bool
#  103    NEIGHBORHOOD_CLINTON                                                  bool
#  104    NEIGHBORHOOD_CLINTON HILL                                             bool
#  105    NEIGHBORHOOD_CLOVE LAKES                                              bool
#  106    NEIGHBORHOOD_CO-OP CITY                                               bool
#  107    NEIGHBORHOOD_COBBLE HILL                                              bool
#  108    NEIGHBORHOOD_COBBLE HILL-WEST                                         bool
#  109    NEIGHBORHOOD_COLLEGE POINT                                            bool
#  110    NEIGHBORHOOD_CONCORD                                                  bool
#  111    NEIGHBORHOOD_CONCORD-FOX HILLS                                        bool
#  112    NEIGHBORHOOD_CONEY ISLAND                                             bool
#  113    NEIGHBORHOOD_CORONA                                                   bool
#  114    NEIGHBORHOOD_COUNTRY CLUB                                             bool
#  115    NEIGHBORHOOD_CROTONA PARK                                             bool
#  116    NEIGHBORHOOD_CROWN HEIGHTS                                            bool
#  117    NEIGHBORHOOD_CYPRESS HILLS                                            bool
#  118    NEIGHBORHOOD_DONGAN HILLS                                             bool
#  119    NEIGHBORHOOD_DONGAN HILLS-COLONY                                      bool
#  120    NEIGHBORHOOD_DONGAN HILLS-OLD TOWN                                    bool
#  121    NEIGHBORHOOD_DOUGLASTON                                               bool
#  122    NEIGHBORHOOD_DOWNTOWN-FULTON FERRY                                    bool
#  123    NEIGHBORHOOD_DOWNTOWN-FULTON MALL                                     bool
#  124    NEIGHBORHOOD_DOWNTOWN-METROTECH                                       bool
#  125    NEIGHBORHOOD_DYKER HEIGHTS                                            bool
#  126    NEIGHBORHOOD_EAST ELMHURST                                            bool
#  127    NEIGHBORHOOD_EAST NEW YORK                                            bool
#  128    NEIGHBORHOOD_EAST TREMONT                                             bool
#  129    NEIGHBORHOOD_EAST VILLAGE                                             bool
#  130    NEIGHBORHOOD_ELMHURST                                                 bool
#  131    NEIGHBORHOOD_ELTINGVILLE                                              bool
#  132    NEIGHBORHOOD_EMERSON HILL                                             bool
#  133    NEIGHBORHOOD_FAR ROCKAWAY                                             bool
#  134    NEIGHBORHOOD_FASHION                                                  bool
#  135    NEIGHBORHOOD_FIELDSTON                                                bool
#  136    NEIGHBORHOOD_FINANCIAL                                                bool
#  137    NEIGHBORHOOD_FLATBUSH-CENTRAL                                         bool
#  138    NEIGHBORHOOD_FLATBUSH-EAST                                            bool
#  139    NEIGHBORHOOD_FLATBUSH-LEFFERTS GARDEN                                 bool
#  140    NEIGHBORHOOD_FLATBUSH-NORTH                                           bool
#  141    NEIGHBORHOOD_FLATIRON                                                 bool
#  142    NEIGHBORHOOD_FLATLANDS                                                bool
#  143    NEIGHBORHOOD_FLORAL PARK                                              bool
#  144    NEIGHBORHOOD_FLUSHING MEADOW PARK                                     bool
#  145    NEIGHBORHOOD_FLUSHING-NORTH                                           bool
#  146    NEIGHBORHOOD_FLUSHING-SOUTH                                           bool
#  147    NEIGHBORHOOD_FORDHAM                                                  bool
#  148    NEIGHBORHOOD_FOREST HILLS                                             bool
#  149    NEIGHBORHOOD_FORT GREENE                                              bool
#  150    NEIGHBORHOOD_FRESH KILLS                                              bool
#  151    NEIGHBORHOOD_FRESH MEADOWS                                            bool
#  152    NEIGHBORHOOD_GERRITSEN BEACH                                          bool
#  153    NEIGHBORHOOD_GLEN OAKS                                                bool
#  154    NEIGHBORHOOD_GLENDALE                                                 bool
#  155    NEIGHBORHOOD_GOWANUS                                                  bool
#  156    NEIGHBORHOOD_GRAMERCY                                                 bool
#  157    NEIGHBORHOOD_GRANT CITY                                               bool
#  158    NEIGHBORHOOD_GRASMERE                                                 bool
#  159    NEIGHBORHOOD_GRAVESEND                                                bool
#  160    NEIGHBORHOOD_GREAT KILLS                                              bool
#  161    NEIGHBORHOOD_GREAT KILLS-BAY TERRACE                                  bool
#  162    NEIGHBORHOOD_GREENPOINT                                               bool
#  163    NEIGHBORHOOD_GREENWICH VILLAGE-CENTRAL                                bool
#  164    NEIGHBORHOOD_GREENWICH VILLAGE-WEST                                   bool
#  165    NEIGHBORHOOD_GRYMES HILL                                              bool
#  166    NEIGHBORHOOD_HAMMELS                                                  bool
#  167    NEIGHBORHOOD_HARLEM-CENTRAL                                           bool
#  168    NEIGHBORHOOD_HARLEM-EAST                                              bool
#  169    NEIGHBORHOOD_HARLEM-UPPER                                             bool
#  170    NEIGHBORHOOD_HARLEM-WEST                                              bool
#  171    NEIGHBORHOOD_HIGHBRIDGE/MORRIS HEIGHTS                                bool
#  172    NEIGHBORHOOD_HILLCREST                                                bool
#  173    NEIGHBORHOOD_HOLLIS                                                   bool
#  174    NEIGHBORHOOD_HOLLIS HILLS                                             bool
#  175    NEIGHBORHOOD_HOLLISWOOD                                               bool
#  176    NEIGHBORHOOD_HOWARD BEACH                                             bool
#  177    NEIGHBORHOOD_HUGUENOT                                                 bool
#  178    NEIGHBORHOOD_HUNTS POINT                                              bool
#  179    NEIGHBORHOOD_INWOOD                                                   bool
#  180    NEIGHBORHOOD_JACKSON HEIGHTS                                          bool
#  181    NEIGHBORHOOD_JAMAICA                                                  bool
#  182    NEIGHBORHOOD_JAMAICA BAY                                              bool
#  183    NEIGHBORHOOD_JAMAICA ESTATES                                          bool
#  184    NEIGHBORHOOD_JAMAICA HILLS                                            bool
#  185    NEIGHBORHOOD_JAVITS CENTER                                            bool
#  186    NEIGHBORHOOD_KENSINGTON                                               bool
#  187    NEIGHBORHOOD_KEW GARDENS                                              bool
#  188    NEIGHBORHOOD_KINGSBRIDGE HTS/UNIV HTS                                 bool
#  189    NEIGHBORHOOD_KINGSBRIDGE/JEROME PARK                                  bool
#  190    NEIGHBORHOOD_KIPS BAY                                                 bool
#  191    NEIGHBORHOOD_LAURELTON                                                bool
#  192    NEIGHBORHOOD_LITTLE ITALY                                             bool
#  193    NEIGHBORHOOD_LITTLE NECK                                              bool
#  194    NEIGHBORHOOD_LIVINGSTON                                               bool
#  195    NEIGHBORHOOD_LONG ISLAND CITY                                         bool
#  196    NEIGHBORHOOD_LOWER EAST SIDE                                          bool
#  197    NEIGHBORHOOD_MADISON                                                  bool
#  198    NEIGHBORHOOD_MANHATTAN BEACH                                          bool
#  199    NEIGHBORHOOD_MANHATTAN VALLEY                                         bool
#  200    NEIGHBORHOOD_MANOR HEIGHTS                                            bool
#  201    NEIGHBORHOOD_MARINE PARK                                              bool
#  202    NEIGHBORHOOD_MARINERS HARBOR                                          bool
#  203    NEIGHBORHOOD_MASPETH                                                  bool
#  204    NEIGHBORHOOD_MELROSE/CONCOURSE                                        bool
#  205    NEIGHBORHOOD_MIDDLE VILLAGE                                           bool
#  206    NEIGHBORHOOD_MIDLAND BEACH                                            bool
#  207    NEIGHBORHOOD_MIDTOWN CBD                                              bool
#  208    NEIGHBORHOOD_MIDTOWN EAST                                             bool
#  209    NEIGHBORHOOD_MIDTOWN WEST                                             bool
#  210    NEIGHBORHOOD_MIDWOOD                                                  bool
#  211    NEIGHBORHOOD_MILL BASIN                                               bool
#  212    NEIGHBORHOOD_MORNINGSIDE HEIGHTS                                      bool
#  213    NEIGHBORHOOD_MORRIS PARK/VAN NEST                                     bool
#  214    NEIGHBORHOOD_MORRISANIA/LONGWOOD                                      bool
#  215    NEIGHBORHOOD_MOTT HAVEN/PORT MORRIS                                   bool
#  216    NEIGHBORHOOD_MOUNT HOPE/MOUNT EDEN                                    bool
#  217    NEIGHBORHOOD_MURRAY HILL                                              bool
#  218    NEIGHBORHOOD_NAVY YARD                                                bool
#  219    NEIGHBORHOOD_NEPONSIT                                                 bool
#  220    NEIGHBORHOOD_NEW BRIGHTON                                             bool
#  221    NEIGHBORHOOD_NEW BRIGHTON-ST. GEORGE                                  bool
#  222    NEIGHBORHOOD_NEW DORP                                                 bool
#  223    NEIGHBORHOOD_NEW DORP-BEACH                                           bool
#  224    NEIGHBORHOOD_NEW DORP-HEIGHTS                                         bool
#  225    NEIGHBORHOOD_NEW SPRINGVILLE                                          bool
#  226    NEIGHBORHOOD_OAKLAND GARDENS                                          bool
#  227    NEIGHBORHOOD_OAKWOOD                                                  bool
#  228    NEIGHBORHOOD_OAKWOOD-BEACH                                            bool
#  229    NEIGHBORHOOD_OCEAN HILL                                               bool
#  230    NEIGHBORHOOD_OCEAN PARKWAY-NORTH                                      bool
#  231    NEIGHBORHOOD_OCEAN PARKWAY-SOUTH                                      bool
#  232    NEIGHBORHOOD_OLD MILL BASIN                                           bool
#  233    NEIGHBORHOOD_OZONE PARK                                               bool
#  234    NEIGHBORHOOD_PARK SLOPE                                               bool
#  235    NEIGHBORHOOD_PARK SLOPE SOUTH                                         bool
#  236    NEIGHBORHOOD_PARKCHESTER                                              bool
#  237    NEIGHBORHOOD_PELHAM GARDENS                                           bool
#  238    NEIGHBORHOOD_PELHAM PARKWAY NORTH                                     bool
#  239    NEIGHBORHOOD_PELHAM PARKWAY SOUTH                                     bool
#  240    NEIGHBORHOOD_PLEASANT PLAINS                                          bool
#  241    NEIGHBORHOOD_PORT IVORY                                               bool
#  242    NEIGHBORHOOD_PORT RICHMOND                                            bool
#  243    NEIGHBORHOOD_PRINCES BAY                                              bool
#  244    NEIGHBORHOOD_PROSPECT HEIGHTS                                         bool
#  245    NEIGHBORHOOD_QUEENS VILLAGE                                           bool
#  246    NEIGHBORHOOD_RED HOOK                                                 bool
#  247    NEIGHBORHOOD_REGO PARK                                                bool
#  248    NEIGHBORHOOD_RICHMOND HILL                                            bool
#  249    NEIGHBORHOOD_RICHMONDTOWN                                             bool
#  250    NEIGHBORHOOD_RICHMONDTOWN-LIGHTHS HILL                                bool
#  251    NEIGHBORHOOD_RIDGEWOOD                                                bool
#  252    NEIGHBORHOOD_RIVERDALE                                                bool
#  253    NEIGHBORHOOD_ROCKAWAY PARK                                            bool
#  254    NEIGHBORHOOD_ROOSEVELT ISLAND                                         bool
#  255    NEIGHBORHOOD_ROSEBANK                                                 bool
#  256    NEIGHBORHOOD_ROSEDALE                                                 bool
#  257    NEIGHBORHOOD_ROSSVILLE                                                bool
#  258    NEIGHBORHOOD_ROSSVILLE-CHARLESTON                                     bool
#  259    NEIGHBORHOOD_ROSSVILLE-RICHMOND VALLEY                                bool
#  260    NEIGHBORHOOD_SCHUYLERVILLE/PELHAM BAY                                 bool
#  261    NEIGHBORHOOD_SEAGATE                                                  bool
#  262    NEIGHBORHOOD_SHEEPSHEAD BAY                                           bool
#  263    NEIGHBORHOOD_SILVER LAKE                                              bool
#  264    NEIGHBORHOOD_SO. JAMAICA-BAISLEY PARK                                 bool
#  265    NEIGHBORHOOD_SOHO                                                     bool
#  266    NEIGHBORHOOD_SOUNDVIEW                                                bool
#  267    NEIGHBORHOOD_SOUTH BEACH                                              bool
#  268    NEIGHBORHOOD_SOUTH JAMAICA                                            bool
#  269    NEIGHBORHOOD_SOUTH OZONE PARK                                         bool
#  270    NEIGHBORHOOD_SOUTHBRIDGE                                              bool
#  271    NEIGHBORHOOD_SPRING CREEK                                             bool
#  272    NEIGHBORHOOD_SPRINGFIELD GARDENS                                      bool
#  273    NEIGHBORHOOD_ST. ALBANS                                               bool
#  274    NEIGHBORHOOD_STAPLETON                                                bool
#  275    NEIGHBORHOOD_STAPLETON-CLIFTON                                        bool
#  276    NEIGHBORHOOD_SUNNYSIDE                                                bool
#  277    NEIGHBORHOOD_SUNSET PARK                                              bool
#  278    NEIGHBORHOOD_THROGS NECK                                              bool
#  279    NEIGHBORHOOD_TODT HILL                                                bool
#  280    NEIGHBORHOOD_TOMPKINSVILLE                                            bool
#  281    NEIGHBORHOOD_TOTTENVILLE                                              bool
#  282    NEIGHBORHOOD_TRAVIS                                                   bool
#  283    NEIGHBORHOOD_TRIBECA                                                  bool
#  284    NEIGHBORHOOD_UPPER EAST SIDE (59-79)                                  bool
#  285    NEIGHBORHOOD_UPPER EAST SIDE (79-96)                                  bool
#  286    NEIGHBORHOOD_UPPER EAST SIDE (96-110)                                 bool
#  287    NEIGHBORHOOD_UPPER WEST SIDE (59-79)                                  bool
#  288    NEIGHBORHOOD_UPPER WEST SIDE (79-96)                                  bool
#  289    NEIGHBORHOOD_UPPER WEST SIDE (96-116)                                 bool
#  290    NEIGHBORHOOD_VAN CORTLANDT PARK                                       bool
#  291    NEIGHBORHOOD_WAKEFIELD                                                bool
#  292    NEIGHBORHOOD_WASHINGTON HEIGHTS LOWER                                 bool
#  293    NEIGHBORHOOD_WASHINGTON HEIGHTS UPPER                                 bool
#  294    NEIGHBORHOOD_WEST NEW BRIGHTON                                        bool
#  295    NEIGHBORHOOD_WESTCHESTER                                              bool
#  296    NEIGHBORHOOD_WESTERLEIGH                                              bool
#  297    NEIGHBORHOOD_WHITESTONE                                               bool
#  298    NEIGHBORHOOD_WILLIAMSBRIDGE                                           bool
#  299    NEIGHBORHOOD_WILLIAMSBURG-CENTRAL                                     bool
#  300    NEIGHBORHOOD_WILLIAMSBURG-EAST                                        bool
#  301    NEIGHBORHOOD_WILLIAMSBURG-NORTH                                       bool
#  302    NEIGHBORHOOD_WILLIAMSBURG-SOUTH                                       bool
#  303    NEIGHBORHOOD_WILLOWBROOK                                              bool
#  304    NEIGHBORHOOD_WINDSOR TERRACE                                          bool
#  305    NEIGHBORHOOD_WOODHAVEN                                                bool
#  306    NEIGHBORHOOD_WOODLAWN                                                 bool
#  307    NEIGHBORHOOD_WOODROW                                                  bool
#  308    NEIGHBORHOOD_WOODSIDE                                                 bool
#  309    NEIGHBORHOOD_WYCKOFF HEIGHTS                                          bool
#  310    ZIP CODE_0                                                            bool
#  311    ZIP CODE_10001                                                        bool
#  312    ZIP CODE_10002                                                        bool
#  313    ZIP CODE_10003                                                        bool
#  314    ZIP CODE_10004                                                        bool
#  315    ZIP CODE_10005                                                        bool
#  316    ZIP CODE_10006                                                        bool
#  317    ZIP CODE_10007                                                        bool
#  318    ZIP CODE_10009                                                        bool
#  319    ZIP CODE_10010                                                        bool
#  320    ZIP CODE_10011                                                        bool
#  321    ZIP CODE_10012                                                        bool
#  322    ZIP CODE_10013                                                        bool
#  323    ZIP CODE_10014                                                        bool
#  324    ZIP CODE_10016                                                        bool
#  325    ZIP CODE_10017                                                        bool
#  326    ZIP CODE_10018                                                        bool
#  327    ZIP CODE_10019                                                        bool
#  328    ZIP CODE_10021                                                        bool
#  329    ZIP CODE_10022                                                        bool
#  330    ZIP CODE_10023                                                        bool
#  331    ZIP CODE_10024                                                        bool
#  332    ZIP CODE_10025                                                        bool
#  333    ZIP CODE_10026                                                        bool
#  334    ZIP CODE_10027                                                        bool
#  335    ZIP CODE_10028                                                        bool
#  336    ZIP CODE_10029                                                        bool
#  337    ZIP CODE_10030                                                        bool
#  338    ZIP CODE_10031                                                        bool
#  339    ZIP CODE_10032                                                        bool
#  340    ZIP CODE_10033                                                        bool
#  341    ZIP CODE_10034                                                        bool
#  342    ZIP CODE_10035                                                        bool
#  343    ZIP CODE_10036                                                        bool
#  344    ZIP CODE_10037                                                        bool
#  345    ZIP CODE_10038                                                        bool
#  346    ZIP CODE_10039                                                        bool
#  347    ZIP CODE_10040                                                        bool
#  348    ZIP CODE_10044                                                        bool
#  349    ZIP CODE_10065                                                        bool
#  350    ZIP CODE_10069                                                        bool
#  351    ZIP CODE_10075                                                        bool
#  352    ZIP CODE_10128                                                        bool
#  353    ZIP CODE_10280                                                        bool
#  354    ZIP CODE_10282                                                        bool
#  355    ZIP CODE_10301                                                        bool
#  356    ZIP CODE_10302                                                        bool
#  357    ZIP CODE_10303                                                        bool
#  358    ZIP CODE_10304                                                        bool
#  359    ZIP CODE_10305                                                        bool
#  360    ZIP CODE_10306                                                        bool
#  361    ZIP CODE_10307                                                        bool
#  362    ZIP CODE_10308                                                        bool
#  363    ZIP CODE_10309                                                        bool
#  364    ZIP CODE_10310                                                        bool
#  365    ZIP CODE_10312                                                        bool
#  366    ZIP CODE_10314                                                        bool
#  367    ZIP CODE_10451                                                        bool
#  368    ZIP CODE_10452                                                        bool
#  369    ZIP CODE_10453                                                        bool
#  370    ZIP CODE_10454                                                        bool
#  371    ZIP CODE_10455                                                        bool
#  372    ZIP CODE_10456                                                        bool
#  373    ZIP CODE_10457                                                        bool
#  374    ZIP CODE_10458                                                        bool
#  375    ZIP CODE_10459                                                        bool
#  376    ZIP CODE_10460                                                        bool
#  377    ZIP CODE_10461                                                        bool
#  378    ZIP CODE_10462                                                        bool
#  379    ZIP CODE_10463                                                        bool
#  380    ZIP CODE_10464                                                        bool
#  381    ZIP CODE_10465                                                        bool
#  382    ZIP CODE_10466                                                        bool
#  383    ZIP CODE_10467                                                        bool
#  384    ZIP CODE_10468                                                        bool
#  385    ZIP CODE_10469                                                        bool
#  386    ZIP CODE_10470                                                        bool
#  387    ZIP CODE_10471                                                        bool
#  388    ZIP CODE_10472                                                        bool
#  389    ZIP CODE_10473                                                        bool
#  390    ZIP CODE_10474                                                        bool
#  391    ZIP CODE_10475                                                        bool
#  392    ZIP CODE_10803                                                        bool
#  393    ZIP CODE_11001                                                        bool
#  394    ZIP CODE_11004                                                        bool
#  395    ZIP CODE_11005                                                        bool
#  396    ZIP CODE_11040                                                        bool
#  397    ZIP CODE_11101                                                        bool
#  398    ZIP CODE_11102                                                        bool
#  399    ZIP CODE_11103                                                        bool
#  400    ZIP CODE_11104                                                        bool
#  401    ZIP CODE_11105                                                        bool
#  402    ZIP CODE_11106                                                        bool
#  403    ZIP CODE_11109                                                        bool
#  404    ZIP CODE_11201                                                        bool
#  405    ZIP CODE_11203                                                        bool
#  406    ZIP CODE_11204                                                        bool
#  407    ZIP CODE_11205                                                        bool
#  408    ZIP CODE_11206                                                        bool
#  409    ZIP CODE_11207                                                        bool
#  410    ZIP CODE_11208                                                        bool
#  411    ZIP CODE_11209                                                        bool
#  412    ZIP CODE_11210                                                        bool
#  413    ZIP CODE_11211                                                        bool
#  414    ZIP CODE_11212                                                        bool
#  415    ZIP CODE_11213                                                        bool
#  416    ZIP CODE_11214                                                        bool
#  417    ZIP CODE_11215                                                        bool
#  418    ZIP CODE_11216                                                        bool
#  419    ZIP CODE_11217                                                        bool
#  420    ZIP CODE_11218                                                        bool
#  421    ZIP CODE_11219                                                        bool
#  422    ZIP CODE_11220                                                        bool
#  423    ZIP CODE_11221                                                        bool
#  424    ZIP CODE_11222                                                        bool
#  425    ZIP CODE_11223                                                        bool
#  426    ZIP CODE_11224                                                        bool
#  427    ZIP CODE_11225                                                        bool
#  428    ZIP CODE_11226                                                        bool
#  429    ZIP CODE_11228                                                        bool
#  430    ZIP CODE_11229                                                        bool
#  431    ZIP CODE_11230                                                        bool
#  432    ZIP CODE_11231                                                        bool
#  433    ZIP CODE_11232                                                        bool
#  434    ZIP CODE_11233                                                        bool
#  435    ZIP CODE_11234                                                        bool
#  436    ZIP CODE_11235                                                        bool
#  437    ZIP CODE_11236                                                        bool
#  438    ZIP CODE_11237                                                        bool
#  439    ZIP CODE_11238                                                        bool
#  440    ZIP CODE_11239                                                        bool
#  441    ZIP CODE_11249                                                        bool
#  442    ZIP CODE_11354                                                        bool
#  443    ZIP CODE_11355                                                        bool
#  444    ZIP CODE_11356                                                        bool
#  445    ZIP CODE_11357                                                        bool
#  446    ZIP CODE_11358                                                        bool
#  447    ZIP CODE_11360                                                        bool
#  448    ZIP CODE_11361                                                        bool
#  449    ZIP CODE_11362                                                        bool
#  450    ZIP CODE_11363                                                        bool
#  451    ZIP CODE_11364                                                        bool
#  452    ZIP CODE_11365                                                        bool
#  453    ZIP CODE_11366                                                        bool
#  454    ZIP CODE_11367                                                        bool
#  455    ZIP CODE_11368                                                        bool
#  456    ZIP CODE_11369                                                        bool
#  457    ZIP CODE_11370                                                        bool
#  458    ZIP CODE_11372                                                        bool
#  459    ZIP CODE_11373                                                        bool
#  460    ZIP CODE_11374                                                        bool
#  461    ZIP CODE_11375                                                        bool
#  462    ZIP CODE_11377                                                        bool
#  463    ZIP CODE_11378                                                        bool
#  464    ZIP CODE_11379                                                        bool
#  465    ZIP CODE_11385                                                        bool
#  466    ZIP CODE_11411                                                        bool
#  467    ZIP CODE_11412                                                        bool
#  468    ZIP CODE_11413                                                        bool
#  469    ZIP CODE_11414                                                        bool
#  470    ZIP CODE_11415                                                        bool
#  471    ZIP CODE_11416                                                        bool
#  472    ZIP CODE_11417                                                        bool
#  473    ZIP CODE_11418                                                        bool
#  474    ZIP CODE_11419                                                        bool
#  475    ZIP CODE_11420                                                        bool
#  476    ZIP CODE_11421                                                        bool
#  477    ZIP CODE_11422                                                        bool
#  478    ZIP CODE_11423                                                        bool
#  479    ZIP CODE_11426                                                        bool
#  480    ZIP CODE_11427                                                        bool
#  481    ZIP CODE_11428                                                        bool
#  482    ZIP CODE_11429                                                        bool
#  483    ZIP CODE_11432                                                        bool
#  484    ZIP CODE_11433                                                        bool
#  485    ZIP CODE_11434                                                        bool
#  486    ZIP CODE_11435                                                        bool
#  487    ZIP CODE_11436                                                        bool
#  488    ZIP CODE_11691                                                        bool
#  489    ZIP CODE_11692                                                        bool
#  490    ZIP CODE_11693                                                        bool
#  491    ZIP CODE_11694                                                        bool
#  492    BLOCK_1                                                               bool
#  493    BLOCK_3                                                               bool
#  494    BLOCK_5                                                               bool
#  495    BLOCK_8                                                               bool
#  496    BLOCK_10                                                              bool
#  497    BLOCK_13                                                              bool
#  498    BLOCK_15                                                              bool
#  499    BLOCK_16                                                              bool
#  500    BLOCK_17                                                              bool
#  501    BLOCK_18                                                              bool
#  502    BLOCK_20                                                              bool
#  503    BLOCK_21                                                              bool
#  504    BLOCK_23                                                              bool
#  505    BLOCK_24                                                              bool
#  506    BLOCK_25                                                              bool
#  507    BLOCK_26                                                              bool
#  508    BLOCK_27                                                              bool
#  509    BLOCK_28                                                              bool
#  510    BLOCK_29                                                              bool
#  511    BLOCK_30                                                              bool
#  512    BLOCK_31                                                              bool
#  513    BLOCK_32                                                              bool
#  514    BLOCK_33                                                              bool
#  515    BLOCK_34                                                              bool
#  516    BLOCK_35                                                              bool
#  517    BLOCK_36                                                              bool
#  518    BLOCK_37                                                              bool
#  519    BLOCK_39                                                              bool
#  520    BLOCK_40                                                              bool
#  521    BLOCK_41                                                              bool
#  522    BLOCK_42                                                              bool
#  523    BLOCK_43                                                              bool
#  524    BLOCK_44                                                              bool
#  525    BLOCK_45                                                              bool
#  526    BLOCK_46                                                              bool
#  527    BLOCK_47                                                              bool
#  528    BLOCK_49                                                              bool
#  529    BLOCK_50                                                              bool
#  530    BLOCK_51                                                              bool
#  531    BLOCK_52                                                              bool
#  532    BLOCK_53                                                              bool
#  533    BLOCK_54                                                              bool
#  534    BLOCK_55                                                              bool
#  535    BLOCK_57                                                              bool
#  536    BLOCK_60                                                              bool
#  537    BLOCK_61                                                              bool
#  538    BLOCK_62                                                              bool
#  539    BLOCK_64                                                              bool
#  540    BLOCK_65                                                              bool
#  541    BLOCK_66                                                              bool
#  542    BLOCK_67                                                              bool
#  543    BLOCK_68                                                              bool
#  544    BLOCK_69                                                              bool
#  545    BLOCK_70                                                              bool
#  546    BLOCK_71                                                              bool
#  547    BLOCK_72                                                              bool
#  548    BLOCK_73                                                              bool
#  549    BLOCK_76                                                              bool
#  550    BLOCK_77                                                              bool
#  551    BLOCK_78                                                              bool
#  552    BLOCK_79                                                              bool
#  553    BLOCK_80                                                              bool
#  554    BLOCK_81                                                              bool
#  555    BLOCK_82                                                              bool
#  556    BLOCK_84                                                              bool
#  557    BLOCK_85                                                              bool
#  558    BLOCK_86                                                              bool
#  559    BLOCK_88                                                              bool
#  560    BLOCK_90                                                              bool
#  561    BLOCK_91                                                              bool
#  562    BLOCK_94                                                              bool
#  563    BLOCK_95                                                              bool
#  564    BLOCK_96                                                              bool
#  565    BLOCK_97                                                              bool
#  566    BLOCK_100                                                             bool
#  567    BLOCK_101                                                             bool
# ...
#  10684  BLOCK_16166                                                           bool
#  10685  BLOCK_16168                                                           bool
#  10686  BLOCK_16169                                                           bool
#  10687  BLOCK_16170                                                           bool
#  10688  BLOCK_16171                                                           bool
#  10689  BLOCK_16173                                                           bool
#  10690  BLOCK_16174                                                           bool
#  10691  BLOCK_16176                                                           bool
#  10692  BLOCK_16180                                                           bool
#  10693  BLOCK_16181                                                           bool
#  10694  BLOCK_16185                                                           bool
#  10695  BLOCK_16194                                                           bool
#  10696  BLOCK_16196                                                           bool
#  10697  BLOCK_16197                                                           bool
#  10698  BLOCK_16202                                                           bool
#  10699  BLOCK_16206                                                           bool
#  10700  BLOCK_16207                                                           bool
#  10701  BLOCK_16208                                                           bool
#  10702  BLOCK_16209                                                           bool
#  10703  BLOCK_16211                                                           bool
#  10704  BLOCK_16212                                                           bool
#  10705  BLOCK_16213                                                           bool
#  10706  BLOCK_16214                                                           bool
#  10707  BLOCK_16219                                                           bool
#  10708  BLOCK_16223                                                           bool
#  10709  BLOCK_16224                                                           bool
#  10710  BLOCK_16225                                                           bool
#  10711  BLOCK_16226                                                           bool
#  10712  BLOCK_16227                                                           bool
#  10713  BLOCK_16228                                                           bool
#  10714  BLOCK_16230                                                           bool
#  10715  BLOCK_16231                                                           bool
#  10716  BLOCK_16234                                                           bool
#  10717  BLOCK_16235                                                           bool
#  10718  BLOCK_16236                                                           bool
#  10719  BLOCK_16237                                                           bool
#  10720  BLOCK_16238                                                           bool
#  10721  BLOCK_16239                                                           bool
#  10722  BLOCK_16244                                                           bool
#  10723  BLOCK_16248                                                           bool
#  10724  BLOCK_16254                                                           bool
#  10725  BLOCK_16256                                                           bool
#  10726  BLOCK_16258                                                           bool
#  10727  BLOCK_16260                                                           bool
#  10728  BLOCK_16261                                                           bool
#  10729  BLOCK_16263                                                           bool
#  10730  BLOCK_16267                                                           bool
#  10731  BLOCK_16268                                                           bool
#  10732  BLOCK_16269                                                           bool
#  10733  BLOCK_16270                                                           bool
#  10734  BLOCK_16272                                                           bool
#  10735  BLOCK_16273                                                           bool
#  10736  BLOCK_16274                                                           bool
#  10737  BLOCK_16275                                                           bool
#  10738  BLOCK_16278                                                           bool
#  10739  BLOCK_16279                                                           bool
#  10740  BLOCK_16282                                                           bool
#  10741  BLOCK_16283                                                           bool
#  10742  BLOCK_16284                                                           bool
#  10743  BLOCK_16285                                                           bool
#  10744  BLOCK_16288                                                           bool
#  10745  BLOCK_16292                                                           bool
#  10746  BLOCK_16293                                                           bool
#  10747  BLOCK_16295                                                           bool
#  10748  BLOCK_16296                                                           bool
#  10749  BLOCK_16299                                                           bool
#  10750  BLOCK_16300                                                           bool
#  10751  BLOCK_16304                                                           bool
#  10752  BLOCK_16305                                                           bool
#  10753  BLOCK_16310                                                           bool
#  10754  BLOCK_16313                                                           bool
#  10755  BLOCK_16315                                                           bool
#  10756  BLOCK_16316                                                           bool
#  10757  BLOCK_16317                                                           bool
#  10758  BLOCK_16319                                                           bool
#  10759  BUILDING CLASS AT TIME OF SALE_A0                                     bool
#  10760  BUILDING CLASS AT TIME OF SALE_A1                                     bool
#  10761  BUILDING CLASS AT TIME OF SALE_A2                                     bool
#  10762  BUILDING CLASS AT TIME OF SALE_A3                                     bool
#  10763  BUILDING CLASS AT TIME OF SALE_A4                                     bool
#  10764  BUILDING CLASS AT TIME OF SALE_A5                                     bool
#  10765  BUILDING CLASS AT TIME OF SALE_A6                                     bool
#  10766  BUILDING CLASS AT TIME OF SALE_A7                                     bool
#  10767  BUILDING CLASS AT TIME OF SALE_A9                                     bool
#  10768  BUILDING CLASS AT TIME OF SALE_B1                                     bool
#  10769  BUILDING CLASS AT TIME OF SALE_B2                                     bool
#  10770  BUILDING CLASS AT TIME OF SALE_B3                                     bool
#  10771  BUILDING CLASS AT TIME OF SALE_B9                                     bool
#  10772  BUILDING CLASS AT TIME OF SALE_C0                                     bool
#  10773  BUILDING CLASS AT TIME OF SALE_C1                                     bool
#  10774  BUILDING CLASS AT TIME OF SALE_C2                                     bool
#  10775  BUILDING CLASS AT TIME OF SALE_C3                                     bool
#  10776  BUILDING CLASS AT TIME OF SALE_C4                                     bool
#  10777  BUILDING CLASS AT TIME OF SALE_C5                                     bool
#  10778  BUILDING CLASS AT TIME OF SALE_C6                                     bool
#  10779  BUILDING CLASS AT TIME OF SALE_C7                                     bool
#  10780  BUILDING CLASS AT TIME OF SALE_C8                                     bool
#  10781  BUILDING CLASS AT TIME OF SALE_C9                                     bool
#  10782  BUILDING CLASS AT TIME OF SALE_D0                                     bool
#  10783  BUILDING CLASS AT TIME OF SALE_D1                                     bool
#  10784  BUILDING CLASS AT TIME OF SALE_D4                                     bool
#  10785  BUILDING CLASS AT TIME OF SALE_D6                                     bool
#  10786  BUILDING CLASS AT TIME OF SALE_D7                                     bool
#  10787  BUILDING CLASS AT TIME OF SALE_E1                                     bool
#  10788  BUILDING CLASS AT TIME OF SALE_E2                                     bool
#  10789  BUILDING CLASS AT TIME OF SALE_E9                                     bool
#  10790  BUILDING CLASS AT TIME OF SALE_F1                                     bool
#  10791  BUILDING CLASS AT TIME OF SALE_F2                                     bool
#  10792  BUILDING CLASS AT TIME OF SALE_F4                                     bool
#  10793  BUILDING CLASS AT TIME OF SALE_F5                                     bool
#  10794  BUILDING CLASS AT TIME OF SALE_F9                                     bool
#  10795  BUILDING CLASS AT TIME OF SALE_G0                                     bool
#  10796  BUILDING CLASS AT TIME OF SALE_G1                                     bool
#  10797  BUILDING CLASS AT TIME OF SALE_G2                                     bool
#  10798  BUILDING CLASS AT TIME OF SALE_G4                                     bool
#  10799  BUILDING CLASS AT TIME OF SALE_G5                                     bool
#  10800  BUILDING CLASS AT TIME OF SALE_G6                                     bool
#  10801  BUILDING CLASS AT TIME OF SALE_G7                                     bool
#  10802  BUILDING CLASS AT TIME OF SALE_G8                                     bool
#  10803  BUILDING CLASS AT TIME OF SALE_G9                                     bool
#  10804  BUILDING CLASS AT TIME OF SALE_GU                                     bool
#  10805  BUILDING CLASS AT TIME OF SALE_GW                                     bool
#  10806  BUILDING CLASS AT TIME OF SALE_H4                                     bool
#  10807  BUILDING CLASS AT TIME OF SALE_H8                                     bool
#  10808  BUILDING CLASS AT TIME OF SALE_HR                                     bool
#  10809  BUILDING CLASS AT TIME OF SALE_I4                                     bool
#  10810  BUILDING CLASS AT TIME OF SALE_I5                                     bool
#  10811  BUILDING CLASS AT TIME OF SALE_I7                                     bool
#  10812  BUILDING CLASS AT TIME OF SALE_I9                                     bool
#  10813  BUILDING CLASS AT TIME OF SALE_K1                                     bool
#  10814  BUILDING CLASS AT TIME OF SALE_K2                                     bool
#  10815  BUILDING CLASS AT TIME OF SALE_K4                                     bool
#  10816  BUILDING CLASS AT TIME OF SALE_K5                                     bool
#  10817  BUILDING CLASS AT TIME OF SALE_K7                                     bool
#  10818  BUILDING CLASS AT TIME OF SALE_K9                                     bool
#  10819  BUILDING CLASS AT TIME OF SALE_L8                                     bool
#  10820  BUILDING CLASS AT TIME OF SALE_L9                                     bool
#  10821  BUILDING CLASS AT TIME OF SALE_M1                                     bool
#  10822  BUILDING CLASS AT TIME OF SALE_M3                                     bool
#  10823  BUILDING CLASS AT TIME OF SALE_M4                                     bool
#  10824  BUILDING CLASS AT TIME OF SALE_M9                                     bool
#  10825  BUILDING CLASS AT TIME OF SALE_N2                                     bool
#  10826  BUILDING CLASS AT TIME OF SALE_N9                                     bool
#  10827  BUILDING CLASS AT TIME OF SALE_O1                                     bool
#  10828  BUILDING CLASS AT TIME OF SALE_O2                                     bool
#  10829  BUILDING CLASS AT TIME OF SALE_O5                                     bool
#  10830  BUILDING CLASS AT TIME OF SALE_O7                                     bool
#  10831  BUILDING CLASS AT TIME OF SALE_O8                                     bool
#  10832  BUILDING CLASS AT TIME OF SALE_P2                                     bool
#  10833  BUILDING CLASS AT TIME OF SALE_P5                                     bool
#  10834  BUILDING CLASS AT TIME OF SALE_P6                                     bool
#  10835  BUILDING CLASS AT TIME OF SALE_P9                                     bool
#  10836  BUILDING CLASS AT TIME OF SALE_Q9                                     bool
#  10837  BUILDING CLASS AT TIME OF SALE_R1                                     bool
#  10838  BUILDING CLASS AT TIME OF SALE_R2                                     bool
#  10839  BUILDING CLASS AT TIME OF SALE_R3                                     bool
#  10840  BUILDING CLASS AT TIME OF SALE_R4                                     bool
#  10841  BUILDING CLASS AT TIME OF SALE_R5                                     bool
#  10842  BUILDING CLASS AT TIME OF SALE_R6                                     bool
#  10843  BUILDING CLASS AT TIME OF SALE_R8                                     bool
#  10844  BUILDING CLASS AT TIME OF SALE_R9                                     bool
#  10845  BUILDING CLASS AT TIME OF SALE_RA                                     bool
#  10846  BUILDING CLASS AT TIME OF SALE_RB                                     bool
#  10847  BUILDING CLASS AT TIME OF SALE_RG                                     bool
#  10848  BUILDING CLASS AT TIME OF SALE_RH                                     bool
#  10849  BUILDING CLASS AT TIME OF SALE_RK                                     bool
#  10850  BUILDING CLASS AT TIME OF SALE_RP                                     bool
#  10851  BUILDING CLASS AT TIME OF SALE_RR                                     bool
#  10852  BUILDING CLASS AT TIME OF SALE_RS                                     bool
#  10853  BUILDING CLASS AT TIME OF SALE_RT                                     bool
#  10854  BUILDING CLASS AT TIME OF SALE_S0                                     bool
#  10855  BUILDING CLASS AT TIME OF SALE_S1                                     bool
#  10856  BUILDING CLASS AT TIME OF SALE_S2                                     bool
#  10857  BUILDING CLASS AT TIME OF SALE_S3                                     bool
#  10858  BUILDING CLASS AT TIME OF SALE_S4                                     bool
#  10859  BUILDING CLASS AT TIME OF SALE_S5                                     bool
#  10860  BUILDING CLASS AT TIME OF SALE_S9                                     bool
#  10861  BUILDING CLASS AT TIME OF SALE_T2                                     bool
#  10862  BUILDING CLASS AT TIME OF SALE_V0                                     bool
#  10863  BUILDING CLASS AT TIME OF SALE_V1                                     bool
#  10864  BUILDING CLASS AT TIME OF SALE_V2                                     bool
#  10865  BUILDING CLASS AT TIME OF SALE_V9                                     bool
#  10866  BUILDING CLASS AT TIME OF SALE_W2                                     bool
#  10867  BUILDING CLASS AT TIME OF SALE_W3                                     bool
#  10868  BUILDING CLASS AT TIME OF SALE_W4                                     bool
#  10869  BUILDING CLASS AT TIME OF SALE_W8                                     bool
#  10870  BUILDING CLASS AT TIME OF SALE_W9                                     bool
#  10871  BUILDING CLASS AT TIME OF SALE_Z0                                     bool
#  10872  BUILDING CLASS AT TIME OF SALE_Z9                                     bool
# dtypes: bool(10873)
# memory usage: 558.6 MB

# %% [markdown]
# # Data Pre Processing

# %%
# 重新从 data_X 中分离出 train_X 和 test_X
train_X = data_X[:num_train_samples].to_numpy()
test_X = data_X[num_train_samples:].to_numpy()

# %% [markdown]
# # Regression

# %%
# 使用梯度提升决策树（GBDT）来训练模型
lgb_train = lgb.Dataset(train_X, train_y)
lgb_eval = lgb.Dataset(test_X, test_y, reference=lgb_train)

params = {
    "num_leaves": 400,
    "feature_fraction": 0.45,
    "learning_rate": 0.05,
    "objective": "mape",
}

lgb_t = lgb.train(params=params, train_set=lgb_train, num_boost_round=2000)
y_pred = lgb_t.predict(test_X)

mean_absolute_percentage_error(test_y, y_pred)
# Out:
# [LightGBM] [Info] Auto-choosing row-wise multi-threading, the overhead of testing was 0.071053 seconds.
# You can set `force_row_wise=true` to remove the overhead.
# And if memory is not enough, you can set `force_col_wise=true`.
# [LightGBM] [Info] Total Bins 2835
# [LightGBM] [Info] Number of data points in the train set: 43064, number of used features: 802
# [LightGBM] [Info] Start training from score 380000.000000
# 0.309445619254423

# %%
pd.DataFrame({"pred": y_pred}).to_csv("2110306206_Arthals.csv")
